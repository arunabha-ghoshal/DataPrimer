# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
gold_df = pd.read_csv('stockprice.data')

# %%
gold_df
# Out:
#          date value  price
# 0  12-05-2014   MAX     43
# 1  12-05-2014   MIN     20
# 2  29-04-2015   MAX     42
# 3  29-04-2015   MIN     21
# 4  26-05-2019   MIN     22
# 5  26-05-2019   MAX     41
# 6  11-11-2017   MAX     46
# 7  11-11-2017   MIN     21

# %%
sns.lineplot(data=gold_df,x='date',y='price',hue='value')

# %%
sns.scatterplot(data=gold_df,x='date',y='price',hue='value',legend='auto')

# %%
sns.jointplot(x='date',y='price',data=gold_df,kind='scatter')

# %%
sns.pairplot(gold_df)
